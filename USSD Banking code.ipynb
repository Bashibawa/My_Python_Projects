# %%
#USSD code for Bank Oprerations
dail = input()
code = "*919#"
#Available Options
open_acct = "1. Open Account"
balance = "2. Balance"
airtime = "3. Airtime"
transfer = "4. Transfer"
#Personal details
acct_bal = 20000
secret_pin = 2022

import random

if dail == code:
    print("Welcome to UBA Bank!")
    print("Please select an option:")
    print(open_acct)
    open_acct = 1
    print(balance)
    balance = 2
    print(airtime)
    airtime = 3
    print(transfer)
    transfer = 4
    selected_option = int(input())
    if selected_option == 1:
        sur_name = input("Enter your Surname:")
        first_name = input("Enter your First name:")
        middle_name = input("Enter your Middle name:")
        bvn = int(input("Enter your 10 digit BVN:"))
        print("Your BVN has been confirmed please proceed...")
        phone_no = int(input("Enter your phone"))
        print(1234)
        four_digit_code = int(input("Input the 4 digit code sent to the above number:"))
        acct_no = random.randint(2415550001, 2415559999)
        if four_digit_code == 1234:
            print("Congratulations {} {} {} your UBA account has successfully been created with account number {}".format(sur_name, first_name, middle_name, acct_no))
            print("Thank you for choosing UBA...")
        else:
            print("Incorrect code please try again!")
    elif selected_option == 2:
        pin = int(input("Please Enter your 4 digit secret pin:"))
        if pin == secret_pin:
            print("Dear Customer your Account balance is #{}:".format(acct_bal))
            print("Thank you for Banking with us...")
        else:
            print("Incorrect PIN please try again...")
    elif selected_option == 3:
        phone_digit = int(input("Please enter the phone number you desire to recharge:"))
        recharge_amount = int(input("Enter the amount you desire to recharge:"))
        if recharge_amount <= acct_bal:
            pin = int(input("Please Enter your 4 digit secret pin:"))
            if pin == secret_pin:
                new_acct_bal = acct_bal - recharge_amount
                print("Your recharge of #{} to {} is successful and your Account balance is now #{}".format(recharge_amount, phone_digit, new_acct_bal))
                print("Thank you for Banking with us...")
            else:
                print("Incorrect PIN please try again...")
        else:
            print("Sorry you don't have sufficient balance, please try another amount...")
    elif selected_option == 4:
        transfer_acct = int(input("Enter destination Account number:"))
        print("Please select the Bank to which your are transfering to:")
        banks = ["1. UBA Bank", "2. GT Bank", "3. First Bank", "4. Zenith Bank", "5. Stanbic IBTC"]
        for bank in banks:
            print(bank)
        selected_bank = int(input())
        transfer_amount = int(input("Enter the amount you desire to transfer:"))
        if transfer_amount <= acct_bal:
            new_acct_bal = acct_bal - transfer_amount
            pin = int(input("Please Enter your 4 digit secret pin:"))
            if pin == secret_pin:
                print("Your transfer of #{} to {} is successful and your Account balance is now #{}".format(transfer_amount, transfer_acct, new_acct_bal))
                print("Thank you for Banking with us...")
            else:
                print("Incorrect PIN please try again...")
        else:
            print("Sorry you don't have sufficient balance, please try another amount...")
    else:
        print("Invalid option selected, please try again...")
else:
    print("Invalid USSD code, please dail the correct code...")
# Out:
# *919#
# Welcome to UBA Bank!
# Please select an option:
# 1. Open Account
# 2. Balance
# 3. Airtime
# 4. Transfer
# 4
# Enter destination Account number:1234567890
# Please select the Bank to which your are transfering to:
# 1. UBA Bank
# 2. GT Bank
# 3. First Bank
# 4. Zenith Bank
# 5. Stanbic IBTC
# 1
# Enter the amount you desire to transfer:2000000
# Sorry you don't have sufficient balance, please try another amount...
