# %% [markdown]
# ## Mock ATM Banking Code

# %%
#Welcome Page
print("Welcome to Access Bank")

option = int(input("Press 1 to proceed or 2 for Cardless Transaction..."))

import random

#Transactions
withdrawal = "1. Withdrawal"
balance = "2. Balance"
airtime = "3. Airtime"
transfer = "4. Transfer"

#cardless_withdrawal = int(input("Please Enter your Phone number to proceed"))

#Personal details
acct_bal = 20000
secret_pin = 2022

#loop
try_again = 1

while try_again == 1:
    if option == 1:
        print("Welcome dear User...")
        card_withdrawal = int(input("Please Enter your secret number:"))
        if card_withdrawal == secret_pin:
            print("Please select an option:")
            print(withdrawal)
            withdrawal = 1
            print(balance)
            balance = 2
            print(airtime)
            airtime = 3
            print(transfer)
            transfer = 4
            selected_option = int(input())
            if selected_option == 1:
                print("Please select an amount:")
                one = "1. #20,000"
                two = "2. #10,000"
                three = "3. #5,000"
                four = "4. #2,000"
                five = "5. #1,000"
                six = "Enter specific amount"
                print(one)
                one = 1
                print(two)
                two = 2
                print(three)
                three = 3
                print(four)
                four = 4
                print(five)
                five = 5
                print(six)
                six = 6
                selected_amount = int(input())
                if selected_amount == 1:
                    acct_balance = acct_bal - 20000
                elif selected_amount == 2:
                    acct_balance = acct_bal - 10000
                elif selected_amount == 3:
                    acct_balance = acct_bal - 5000
                elif selected_amount == 4:
                    acct_balance = acct_bal - 2000
                elif selected_amount == 5:
                    acct_balance = acct_bal - 1000
                elif selected_amount == 6:
                    specific_amount = int((input("Enter specific amount:")))
                    acct_balance = acct_bal - specific_amount
                else:
                    print("Error! Try again please select a valid amount")
                print("Please wait for your transaction is processing...")
                print("Please take your cash...")
                print("DEBIT ALERT")
                print("Your Acct XXXXXX", random.randint(1999, 9999), "has been debited")
                print("ATM Withdrawal")
                print("Acct balance: #", acct_balance)
            elif selected_option == 2:
                print("Dear User your Account Balance is #", acct_bal)
            elif selected_option == 3:
                phone_digit = int(input("Please enter the phone number you desire to recharge:"))
                recharge_amount = int(input("Enter the amount you desire to recharge:"))
                if recharge_amount <= acct_bal:
                    print("Please select your phone Network:")
                    networks = ["1. MTN", "2. GLO", "3. Airtel", "4. 9mobile"]
                    for network in networks:
                        print(network)
                    selected_network = int(input())
                    new_acct_bal = acct_bal - recharge_amount
                    print("Your recharge of #{} to {} is successful".format(recharge_amount, phone_digit))
                    print("Thank you for Banking with us...")
                    print("DEBIT ALERT")
                    print("Your Acct XXXXXX", random.randint(1999, 9999), "has been debited")
                    print("ATM Recharge")
                    print("Acct balance: #", new_acct_bal)
                else:
                    print("Sorry you don't have sufficient balance, please try another amount...")
            elif selected_option == 4:
                transfer_acct = int(input("Enter destination Account number:"))
                print("Please select the Bank to which your are transfering to:")
                banks = ["1. UBA Bank", "2. GT Bank", "3. First Bank", "4. Zenith Bank", "5. Stanbic IBTC"]
                for bank in banks:
                    print(bank)
                selected_bank = int(input())
                transfer_amount = int(input("Enter the amount you desire to transfer:"))
                if transfer_amount <= acct_bal:
                    new_acct_bal = acct_bal - transfer_amount
                    print("Your transfer of #{} to {} is successful...".format(transfer_amount, transfer_acct))
                    print("Thank you for Banking with us...")
                    print("DEBIT ALERT")
                    print("Your Acct XXXXXX", random.randint(1999, 9999), "has been debited")
                    print("ATM Transfer")
                    print("Acct balance:# ", new_acct_bal)
                else:
                    print("Sorry you don't have sufficient balance, please try another amount...")
            else:
                print("Invalid option selected, please try again...")
        else:
            print("Incorrect PIN please try again...")
    proceed = input("Do you want to perform another transaction? Y/N")
    if proceed == "Y":
        continue
    elif proceed == "N":
        break
    else:
        print("Invalid option try again...")
# Out:
# Welcome to Access Bank
# Press 1 to proceed or 2 for Cardless Transaction...1
# Welcome dear User...
# Please Enter your secret number:2022
# Please select an option:
# 1. Withdrawal
# 2. Balance
# 3. Airtime
# 4. Transfer
# 2
# Dear User your Account Balance is # 20000
# Do you want to perform another transaction? Y/NY
# Welcome dear User...
# Please Enter your secret number:2022
# Please select an option:
# 1
# 2
# 3
# 4
# 1
# Please select an amount:
# 1. #20,000
# 2. #10,000
# 3. #5,000
# 4. #2,000
# 5. #1,000
# Enter specific amount
# 2
# Please wait for your transaction is processing...
# Please take your cash...
# DEBIT ALERT
# Your Acct XXXXXX 5617 has been debited
# ATM Withdrawal
# Acct balance: # 10000
# Do you want to perform another transaction? Y/NY
# Welcome dear User...
# Please Enter your secret number:2022
# Please select an option:
# 1
# 2
# 3
# 4
# 3
# Please enter the phone number you desire to recharge:09029582858
# Enter the amount you desire to recharge:500
# ...
